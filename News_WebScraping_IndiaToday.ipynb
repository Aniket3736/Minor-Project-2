# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket3736/Minor-Project-2/blob/main/News_WebScraping_IndiaToday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the libararies
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time

# %%
#Create lists to store the scrapped data
paragraph_statements = []
quote_statements = []

# %%
#Create a function to scrape the website
def scrape_website(page_number):
  page_num = str(page_number)
  URL = 'https://www.indiatoday.in/india?page='+page_num
  webpage = requests.get(URL)
  soup = BeautifulSoup(webpage.text, 'html.parser')

#Get the location of the information
  statement_quote = soup.find_all('div',attrs = {'class': 'detail'}) #Location of the statement

#Loop through the statement_quote
  for i in statement_quote:
    link2 = i.find_all('a')
    link3 = i.find_all('p')
    statement_text_quote = link2[0].text.strip()
    statement_text_paragraph = link3[0].text.strip()
    quote_statements.append(statement_text_quote)
    paragraph_statements.append(statement_text_paragraph)

# %%
#Loop through n to 'm-1' webpages to scrape the data
n,m = 501,502
for i in range(n,m):
  scrape_website(i)

# %%
#Create the dataframe
data = pd.DataFrame(columns = ['quotes','paragraph'])
data['quotes'] = quote_statements
data['paragraph'] = paragraph_statements

#show the data
data
# Out:
#                                                 quotes  \
# 0    You’re trustee of state, but looted it: Raghub...
# 1    Youth Congress workers stage protest against B...
# 2    National level action plan need of the hour to...
# 3    CBI arrests its four officers on corruption ch...
# 4    Kashmiri Pandit killed by terrorists in J&K's ...
# ..                                                 ...
# 99   Allahabad HC rejects plea seeking to open 22 c...
# 100  Haryana labourer with two fans and bulbs gets ...
# 101  Golden tiger spotted in Assam’s Kaziranga Nati...
# 102  Who were behind Mohali blast? 3 days after inc...
# 103  IAS Pooja Singhal took bribes, recovered cash ...
#
#                                              paragraph
# 0    Taking a dig at Jharkhand Chief Minister Heman...
# 1    Youth Congress workers in Bhopal clashed with ...
# 2    Aaditya Thackeray stressed the need for a Nati...
# 3    CBI arrested four of its own sub-inspectors on...
# 4    A Kashmiri Pandit, Rahul Bhat, was shot at by ...
# ..                                                 ...
# 99   The Allahabad High Court has rejected the peti...
# 100  A poor labourer from Fatehabad having two bulb...
# 101  A rare species of golden tiger was spotted by ...
# 102  A rocket-propelled grenade (RPG) was fired at ...
# 103  IAS officer Pooja Singhal's CA on Thursday rev...
#
# [104 rows x 2 columns]
